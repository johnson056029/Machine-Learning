# %%
from READFILE import *
from INPUT import *
from LSE import *
from NEWTONS_METHOD import *
from OUTPUT import *
import matplotlib.pyplot as plt

data = read_data_points("testfile.txt")

num_bases, lambda_ = get_input()

fitting_line, total_error = LSE(data, num_bases, lambda_)
output("LSE", fitting_line, total_error, data)

fitting_line, total_error = Newton(data, num_bases)
output("Newton's method", fitting_line, total_error, data)
# Out:
# number of bases: 3
# lambda: 10000
#
# LSE:
# Fitting line:  0.8345332827002847x^2 + 0.09314819831918801x + 0.04695069927346922
# Total error:  22649.738493024175
# :
# Fitting line:  3.023853393486571x^2 + 4.9061902638638x - 0.2314017560877174
# Total error:  26.55995949933306
